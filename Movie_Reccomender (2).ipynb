# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
movie_ids_titles=pd.read_csv("movies.csv.zip")
movie_ids_titles.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
movie_ids_titles.shape
# Out:
# (62423, 3)

# %%
movie_ids_ratings=pd.read_csv("ratings.csv")
movie_ids_ratings.head()
# Out:
#    userId  movieId  rating     timestamp
# 0       1      296     5.0  1.147880e+09
# 1       1      306     3.5  1.147869e+09
# 2       1      307     5.0  1.147869e+09
# 3       1      665     5.0  1.147879e+09
# 4       1      899     3.5  1.147869e+09

# %%
movie_ids_ratings.shape
# Out:
# (250448, 4)

# %%
movie_ids_ratings.drop(["timestamp"],inplace=True,axis=1)
movie_ids_ratings.head()
# Out:
#    userId  movieId  rating
# 0       1      296     5.0
# 1       1      306     3.5
# 2       1      307     5.0
# 3       1      665     5.0
# 4       1      899     3.5

# %%
merged_movie_df=pd.merge(movie_ids_ratings,movie_ids_titles, on="movieId")
merged_movie_df.head()
# Out:
#    userId  movieId  rating                title                       genres
# 0       1      296     5.0  Pulp Fiction (1994)  Comedy|Crime|Drama|Thriller
# 1       3      296     5.0  Pulp Fiction (1994)  Comedy|Crime|Drama|Thriller
# 2       4      296     4.0  Pulp Fiction (1994)  Comedy|Crime|Drama|Thriller
# 3       5      296     4.0  Pulp Fiction (1994)  Comedy|Crime|Drama|Thriller
# 4       7      296     4.0  Pulp Fiction (1994)  Comedy|Crime|Drama|Thriller

# %%
merged_movie_df.groupby('title').describe()
# Out:
#                                         userId                               \
#                                          count     mean         std     min
# title
# "Great Performances" Cats (1998)           2.0  1272.00   14.142136  1262.0
# $5 a Day (2008)                            1.0    58.00         NaN    58.0
# '71 (2014)                                 4.0   977.25  449.729085   426.0
# 'Hellboy': The Seeds of Creation (2004)    1.0  1212.00         NaN  1212.0
# 'Round Midnight (1986)                     3.0   865.00  845.865829    58.0
# ...                                        ...      ...         ...     ...
# Начальник                                  1.0  1652.00         NaN  1652.0
# Обезьянки и грабители (1985)               1.0   541.00         NaN   541.0
# Он вам не Димон (2017)                     1.0   541.00         NaN   541.0
# Приключения Домовёнка (1986)               2.0   769.00  322.440692   541.0
# Принцесса и Людоед (1977)                  1.0   541.00         NaN   541.0
#
#                                                                           \
#                                              25%     50%     75%     max
# title
# "Great Performances" Cats (1998)         1267.00  1272.0  1277.0  1282.0
# $5 a Day (2008)                            58.00    58.0    58.0    58.0
# '71 (2014)                                707.25  1041.0  1311.0  1401.0
# 'Hellboy': The Seeds of Creation (2004)  1212.00  1212.0  1212.0  1212.0
# 'Round Midnight (1986)                    425.00   792.0  1268.5  1745.0
# ...                                          ...     ...     ...     ...
# Начальник                                1652.00  1652.0  1652.0  1652.0
# Обезьянки и грабители (1985)              541.00   541.0   541.0   541.0
# Он вам не Димон (2017)                    541.00   541.0   541.0   541.0
# Приключения Домовёнка (1986)              655.00   769.0   883.0   997.0
# Принцесса и Людоед (1977)                 541.00   541.0   541.0   541.0
#
#                                         movieId            ...            \
#                                           count      mean  ...       75%
# title                                                      ...
# "Great Performances" Cats (1998)            2.0   51372.0  ...   51372.0
# $5 a Day (2008)                             1.0   80361.0  ...   80361.0
# '71 (2014)                                  4.0  117867.0  ...  117867.0
# 'Hellboy': The Seeds of Creation (2004)     1.0   97757.0  ...   97757.0
# 'Round Midnight (1986)                      3.0   26564.0  ...   26564.0
# ...                                         ...       ...  ...       ...
# Начальник                                   1.0  183247.0  ...  183247.0
# Обезьянки и грабители (1985)                1.0  188365.0  ...  188365.0
# Он вам не Димон (2017)                      1.0  173817.0  ...  173817.0
# Приключения Домовёнка (1986)                2.0  173813.0  ...  173813.0
# Принцесса и Людоед (1977)                   1.0  181219.0  ...  181219.0
#
#                                                   rating                   \
#                                               max  count   mean       std
# title
# "Great Performances" Cats (1998)          51372.0    2.0  4.500  0.000000
# $5 a Day (2008)                           80361.0    1.0  4.000       NaN
# '71 (2014)                               117867.0    4.0  2.375  0.629153
# 'Hellboy': The Seeds of Creation (2004)   97757.0    1.0  4.000       NaN
# 'Round Midnight (1986)                    26564.0    3.0  4.000  0.000000
# ...                                           ...    ...    ...       ...
# Начальник                                183247.0    1.0  4.000       NaN
# Обезьянки и грабители (1985)             188365.0    1.0  4.000       NaN
# Он вам не Димон (2017)                   173817.0    1.0  4.500       NaN
# Приключения Домовёнка (1986)             173813.0    2.0  3.750  0.353553
# Принцесса и Людоед (1977)                181219.0    1.0  4.000       NaN
#
#
#                                          min    25%   50%    75%  max
# title
# "Great Performances" Cats (1998)         4.5  4.500  4.50  4.500  4.5
# $5 a Day (2008)                          4.0  4.000  4.00  4.000  4.0
# '71 (2014)                               1.5  2.250  2.50  2.625  3.0
# 'Hellboy': The Seeds of Creation (2004)  4.0  4.000  4.00  4.000  4.0
# 'Round Midnight (1986)                   4.0  4.000  4.00  4.000  4.0
# ...                                      ...    ...   ...    ...  ...
# Начальник                                4.0  4.000  4.00  4.000  4.0
# Обезьянки и грабители (1985)             4.0  4.000  4.00  4.000  4.0
# Он вам не Димон (2017)                   4.5  4.500  4.50  4.500  4.5
# Приключения Домовёнка (1986)             3.5  3.625  3.75  3.875  4.0
# Принцесса и Людоед (1977)                4.0  4.000  4.00  4.000  4.0
#
# [13986 rows x 24 columns]

# %%
merged_movie_df.groupby('title')['rating'].mean().head()
# Out:
# title
# "Great Performances" Cats (1998)           4.500
# $5 a Day (2008)                            4.000
# '71 (2014)                                 2.375
# 'Hellboy': The Seeds of Creation (2004)    4.000
# 'Round Midnight (1986)                     4.000
# Name: rating, dtype: float64

# %%
merged_movie_df.groupby('title')['rating'].mean().sort_values(ascending=False).head()
# Out:
# title
# Patton Oswalt: Finest Hour (2011)    5.0
# O Pátio das Cantigas (1942)          5.0
# The Lorax (1972)                     5.0
# Big Bad Mama (1974)                  5.0
# Once Brothers (2010)                 5.0
# Name: rating, dtype: float64

# %%
merged_movie_df.groupby('title')['rating'].count().sort_values(ascending=False).head()
# Out:
# title
# Forrest Gump (1994)                 873
# Pulp Fiction (1994)                 863
# Shawshank Redemption, The (1994)    862
# Silence of the Lambs, The (1991)    795
# Matrix, The (1999)                  782
# Name: rating, dtype: int64

# %%
movie_rating_mean_count=pd.DataFrame(columns=['rating_mean','rating_count'])
movie_rating_mean_count['rating_mean']=merged_movie_df.groupby('title')['rating'].mean()
movie_rating_mean_count['rating_count']=merged_movie_df.groupby('title')['rating'].count()
movie_rating_mean_count.head()
# Out:
#                                          rating_mean  rating_count
# title
# "Great Performances" Cats (1998)               4.500             2
# $5 a Day (2008)                                4.000             1
# '71 (2014)                                     2.375             4
# 'Hellboy': The Seeds of Creation (2004)        4.000             1
# 'Round Midnight (1986)                         4.000             3

# %%
plt.figure(figsize=(10,6))
sns.set_style("whitegrid")
movie_rating_mean_count['rating_mean'].hist(bins=25,color='red')
# Out:
# <Axes: >

# %%
plt.figure(figsize=(10,6))
sns.set_style("whitegrid")
movie_rating_mean_count['rating_count'].hist(bins=33,color='silver')
# Out:
# <Axes: >

# %%
plt.figure(figsize=(10,7))
sns.set_style("darkgrid")
sns.regplot(x="rating_mean",y="rating_count",data=movie_rating_mean_count,color="black")
# Out:
# <Axes: xlabel='rating_mean', ylabel='rating_count'>

# %%
#average of top 5 highest number of ratings
movie_rating_mean_count.sort_values(by='rating_count',ascending=False).head(5)
# Out:
#                                   rating_mean  rating_count
# title
# Forrest Gump (1994)                  4.030928           873
# Pulp Fiction (1994)                  4.175550           863
# Shawshank Redemption, The (1994)     4.436775           862
# Silence of the Lambs, The (1991)     4.119497           795
# Matrix, The (1999)                   4.149616           782

# %%
#item based collaborative filtering
user_movie_rating_matrix=merged_movie_df.pivot_table(index='userId',columns='title',values='rating')
user_movie_rating_matrix
# Out:
# title   "Great Performances" Cats (1998)  $5 a Day (2008)  '71 (2014)  \
# userId
# 1                                    NaN              NaN         NaN
# 2                                    NaN              NaN         NaN
# 3                                    NaN              NaN         NaN
# 4                                    NaN              NaN         NaN
# 5                                    NaN              NaN         NaN
# ...                                  ...              ...         ...
# 1751                                 NaN              NaN         NaN
# 1752                                 NaN              NaN         NaN
# 1753                                 NaN              NaN         NaN
# 1754                                 NaN              NaN         NaN
# 1755                                 NaN              NaN         NaN
#
# title   'Hellboy': The Seeds of Creation (2004)  'Round Midnight (1986)  \
# userId
# 1                                           NaN                     NaN
# 2                                           NaN                     NaN
# 3                                           NaN                     NaN
# 4                                           NaN                     NaN
# 5                                           NaN                     NaN
# ...                                         ...                     ...
# 1751                                        NaN                     NaN
# 1752                                        NaN                     NaN
# 1753                                        NaN                     NaN
# 1754                                        NaN                     NaN
# 1755                                        NaN                     NaN
#
# title   'Salem's Lot (2004)  'Til There Was You (1997)  'burbs, The (1989)  \
# userId
# 1                       NaN                        NaN                 NaN
# 2                       NaN                        NaN                 NaN
# 3                       NaN                        NaN                 NaN
# 4                       NaN                        NaN                 NaN
# 5                       NaN                        NaN                 NaN
# ...                     ...                        ...                 ...
# 1751                    NaN                        NaN                 NaN
# 1752                    NaN                        NaN                 NaN
# 1753                    NaN                        NaN                 NaN
# 1754                    NaN                        NaN                 NaN
# 1755                    NaN                        NaN                 NaN
#
# title   'night Mother (1986)  (500) Days of Summer (2009)  ...  \
# userId                                                     ...
# 1                        NaN                          NaN  ...
# 2                        NaN                          NaN  ...
# 3                        NaN                          NaN  ...
# 4                        NaN                          NaN  ...
# 5                        NaN                          NaN  ...
# ...                      ...                          ...  ...
# 1751                     NaN                          NaN  ...
# 1752                     NaN                          NaN  ...
# 1753                     NaN                          NaN  ...
# 1754                     NaN                          NaN  ...
# 1755                     NaN                          NaN  ...
#
# title   Šíleně smutná princezna (1968)  В движении (2002)  \
# userId
# 1                                  NaN                NaN
# 2                                  NaN                NaN
# 3                                  NaN                NaN
# 4                                  NaN                NaN
# 5                                  NaN                NaN
# ...                                ...                ...
# 1751                               NaN                NaN
# 1752                               NaN                NaN
# 1753                               NaN                NaN
# 1754                               NaN                NaN
# 1755                               NaN                NaN
#
# title   Кентервильское привидение (1970)  Когда зажигаются ёлки (1950)  \
# userId
# 1                                    NaN                           NaN
# 2                                    NaN                           NaN
# 3                                    NaN                           NaN
# 4                                    NaN                           NaN
# 5                                    NaN                           NaN
# ...                                  ...                           ...
# 1751                                 NaN                           NaN
# 1752                                 NaN                           NaN
# 1753                                 NaN                           NaN
# 1754                                 NaN                           NaN
# 1755                                 NaN                           NaN
#
# title   Ландыш серебристый (2000)  Начальник  Обезьянки и грабители (1985)  \
# userId
# 1                             NaN        NaN                           NaN
# 2                             NaN        NaN                           NaN
# 3                             NaN        NaN                           NaN
# 4                             NaN        NaN                           NaN
# 5                             NaN        NaN                           NaN
# ...                           ...        ...                           ...
# 1751                          NaN        NaN                           NaN
# 1752                          NaN        NaN                           NaN
# 1753                          NaN        NaN                           NaN
# 1754                          NaN        NaN                           NaN
# 1755                          NaN        NaN                           NaN
#
# title   Он вам не Димон (2017)  Приключения Домовёнка (1986)  \
# userId
# 1                          NaN                           NaN
# 2                          NaN                           NaN
# 3                          NaN                           NaN
# 4                          NaN                           NaN
# 5                          NaN                           NaN
# ...                        ...                           ...
# 1751                       NaN                           NaN
# 1752                       NaN                           NaN
# 1753                       NaN                           NaN
# 1754                       NaN                           NaN
# 1755                       NaN                           NaN
#
# title   Принцесса и Людоед (1977)
# userId
# 1                             NaN
# 2                             NaN
# 3                             NaN
# 4                             NaN
# 5                             NaN
# ...                           ...
# 1751                          NaN
# 1752                          NaN
# 1753                          NaN
# 1754                          NaN
# 1755                          NaN
#
# [1755 rows x 13986 columns]

# %%
user_movie_rating_matrix.shape
# Out:
# (1755, 13986)

# %%
pulp_fiction_ratings=user_movie_rating_matrix["Pulp Fiction (1994)"]

# %%
pulp_fiction_correlations=pd.DataFrame(user_movie_rating_matrix.corrwith(pulp_fiction_ratings),columns=['pf_corr'])
# Out:
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2889: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2748: RuntimeWarning: divide by zero encountered in divide
#   c *= np.true_divide(1, fact)

# %%
pulp_fiction_correlations.sort_values("pf_corr",ascending=False).head(10)
# Out:
#                                                     pf_corr
# title
# Кентервильское привидение (1970)                        1.0
# Divorce, Le (2003)                                      1.0
# Devil Inside, The (2012)                                1.0
# Devil and Max Devlin, The (1981)                        1.0
# Devil, Probably, The (Diable probablement, Le) ...      1.0
# Diary of a Country Priest (Journal d'un curé de...      1.0
# All Eyez on Me (2016)                                   1.0
# Rendezvous in Paris (Rendez-vous de Paris, Les)...      1.0
# All About Steve (2009)                                  1.0
# Regret (2013)                                           1.0

# %%
pulp_fiction_correlations=pulp_fiction_correlations.join(movie_rating_mean_count['rating_count'])

# %%
pulp_fiction_correlations.head(10)
# Out:
#                                           pf_corr  rating_count
# title
# "Great Performances" Cats (1998)              NaN             2
# $5 a Day (2008)                               NaN             1
# '71 (2014)                              -0.207514             4
# 'Hellboy': The Seeds of Creation (2004)       NaN             1
# 'Round Midnight (1986)                        NaN             3
# 'Salem's Lot (2004)                           NaN             2
# 'Til There Was You (1997)                0.960769             5
# 'burbs, The (1989)                       0.292676            37
# 'night Mother (1986)                    -0.359211             3
# (500) Days of Summer (2009)              0.293021           111

# %%
pulp_fiction_correlations_50=pulp_fiction_correlations[pulp_fiction_correlations['rating_count']>50]
pulp_fiction_correlations_50.sort_values("pf_corr",ascending=False).head()
# Out:
#                                                      pf_corr  rating_count
# title
# Pulp Fiction (1994)                                 1.000000           863
# Kill Bill: Vol. 1 (2003)                            0.604022           346
# Falling Down (1993)                                 0.585768            65
# Girl with the Dragon Tattoo, The (Män som hatar...  0.558038            52
# Metropolis (1927)                                   0.545185            56

# %%
all_movie_correlations=user_movie_rating_matrix.corr(method="pearson",min_periods=50)

# %% [markdown]
# Finding recommendation on multiple movies:

# %%
all_movie_correlations.head()

# %%
movie_data=[['Falling Down (1993)',4.0],["Metropolis (1927)",3.5],["Kill Bill: Vol. 1 (2003)",4.0]]
test_movies=pd.DataFrame(movie_data,columns=['Movie_Name','Movie_Rating'])
test_movies.head()
# Out:
#                  Movie_Name  Movie_Rating
# 0       Falling Down (1993)           4.0
# 1         Metropolis (1927)           3.5
# 2  Kill Bill: Vol. 1 (2003)           4.0

# %%
#based on mentioned 3 movies, the movies are recommended:
print(test_movies['Movie_Name'][0])
print(test_movies['Movie_Rating'][0])
# Out:
# Falling Down (1993)
# 4.0

# %%
all_movie_correlations['Falling Down (1993)'].dropna()
# Out:
# title
# Falling Down (1993)                                                               1.000000
# Forrest Gump (1994)                                                               0.286241
# Jurassic Park (1993)                                                              0.188910
# Matrix, The (1999)                                                                0.265765
# Raiders of the Lost Ark (Indiana Jones and the Raiders of the Lost Ark) (1981)    0.175873
# Shawshank Redemption, The (1994)                                                  0.137370
# Star Wars: Episode V - The Empire Strikes Back (1980)                             0.239867
# Terminator 2: Judgment Day (1991)                                                 0.232986
# Name: Falling Down (1993), dtype: float64

# %%
recommended_movies=pd.Series()

# %%
import pandas as pd

recommended_movies = pd.Series()

for i in range(0,2):
  movie = all_movie_correlations[test_movies['Movie_Name'][i]].dropna()
  movie = movie.map(lambda movie_corr: movie_corr * test_movies['Movie_Rating'][i])
  recommended_movies = pd.concat([recommended_movies, movie])

# %%
recommended_movies.sort_values(inplace=True, ascending=False)
print(recommended_movies.head(10))
# Out:
# Falling Down (1993)                                                               4.000000
# Metropolis (1927)                                                                 3.500000
# Forrest Gump (1994)                                                               1.144963
# Matrix, The (1999)                                                                1.063059
# Star Wars: Episode V - The Empire Strikes Back (1980)                             0.959469
# Terminator 2: Judgment Day (1991)                                                 0.931944
# Jurassic Park (1993)                                                              0.755640
# Raiders of the Lost Ark (Indiana Jones and the Raiders of the Lost Ark) (1981)    0.703491
# Shawshank Redemption, The (1994)                                                  0.549481
# dtype: float64
